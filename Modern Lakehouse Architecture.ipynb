# %% [markdown]
# # ````Welcome to Data + AI Summit 2021````
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTe0AKMu5fuPm_vCOaeILtMxGYQABZQbaMpvg&usqp=CAU"width=100/><img src="https://docs.delta.io/latest/_static/delta-lake-logo.png" width=150/> <img src="https://avatars.githubusercontent.com/u/10746780?s=280&v=4" width=100/><img src="https://www.mlflow.org/docs/latest/_static/MLflow-logo-final-black.png"width=100/>
# ###Becoming a Data Driven Organization with Modern Lakehouse
#
# In this demonstration, we will be building a unified pipeline with Lakehouse architecture:
#
# - How to ingest streaming data into raw table
# - How to ingest your existing data in batch process
# - How to build the Data Engineering pipelines using **Bronze/Silver/Gold layers with Delta**
# - Leverage **Lakehouse architecture for Databricks SQL (visualization) and downstream ML pipelines**

# %% [markdown]
# ##Databricks components
# * Databricks Runtime 4.2 or greater
#
# ## Datasets Used
# * Read Wikipedia edits in real time, with a multitude of different languages.
# * Aggregate the anonymous edits by country, over a window, to see who's editing the English Wikipedia over time.

# %%
# %run "./Includes/Classroom-Setup-07"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# Created user-specific database
# Using the database <b style="color:green">vini_jaiswal_databricks_com_architecture_dbilp</b>.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Imported Test Library...
# <div>Declared course-specific utility methods:</div>
# <li>Declared <b style="color:green">untilStreamIsReady(<i>name:String</i>)</b> to control workflow</li>
# <div>Declared module-specific resources:</div>
# <li>Declared <b style="color:green">basePath:String</b> = <b style="color:blue">dbfs:/user/vini.jaiswal@databricks.com/delta-il07p</b></li>
# Removed temp files from dbfs:/user/vini.jaiswal@databricks.com/delta-il07p

# %% [markdown]
# -sandbox
# ##  Delta Medallion Architecture
#
#
#
#
# <div><img src="https://files.training.databricks.com/images/eLearning/Delta/delta.png" style="height: 350px"/></div><br/>

# %%
bronzePath     = basePath + "/wikipedia/bronze.delta"
silverPath     = basePath + "/wikipedia/silver.delta"
checkpointPath = basePath + "/checkpoints"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, BooleanType

schema = StructType([
  StructField("channel", StringType(), True),
  StructField("comment", StringType(), True),
  StructField("delta", IntegerType(), True),
  StructField("flag", StringType(), True),
  StructField("geocoding", StructType([                 
    StructField("city", StringType(), True),
    StructField("country", StringType(), True),
    StructField("countryCode2", StringType(), True),
    StructField("countryCode3", StringType(), True),
    StructField("stateProvince", StringType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
  ]), True),
  StructField("isAnonymous", BooleanType(), True),    
  StructField("isNewPage", BooleanType(), True),
  StructField("isRobot", BooleanType(), True),
  StructField("isUnpatrolled", BooleanType(), True),
  StructField("namespace", StringType(), True),         
  StructField("page", StringType(), True),             
  StructField("pageURL", StringType(), True),         
  StructField("timestamp", StringType(), True),     
  StructField("url", StringType(), True),
  StructField("user", StringType(), True),            
  StructField("userURL", StringType(), True),
  StructField("wikipediaURL", StringType(), True),
  StructField("wikipedia", StringType(), True),         
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import from_json, col
(spark.readStream
  .format("kafka")  
  .option("kafka.bootstrap.servers", "server1.databricks.training:9092") 
  .option("subscribe", "en")
  .load()
  .withColumn("json", from_json(col("value").cast("string"), schema))
  .select(col("timestamp").alias("kafka_timestamp"), col("json.*"))
  .writeStream
  .format("delta")
  .option("checkpointLocation", checkpointPath + "/bronze")
  .outputMode("append")
  .queryName("stream_1p")
  .start(bronzePath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[59]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f619d7bdd00&gt;</div>

# %% [markdown]
# Wait until stream is done initializing...

# %%
untilStreamIsReady("stream_1p")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream is active and ready.
# </div>

# %% [markdown]
# Take a look the first row of the raw table without explicitly creating a table.

# %%
bronzeDF = spark.sql("SELECT * FROM delta.`{}` limit 3".format(bronzePath))
display(bronzeDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>kafka_timestamp</th><th>channel</th><th>comment</th><th>delta</th><th>flag</th><th>geocoding</th><th>isAnonymous</th><th>isNewPage</th><th>isRobot</th><th>isUnpatrolled</th><th>namespace</th><th>page</th><th>pageURL</th><th>timestamp</th><th>url</th><th>user</th><th>userURL</th><th>wikipediaURL</th><th>wikipedia</th></tr></thead><tbody><tr><td>1969-12-31T23:59:59.999+0000</td><td>#en.wikipedia</td><td>[[WP:AES|���]]Created page with '<noinclude> __NOINDEX__ Please do not edit this page.</noinclude><includeonly> ���<!--ffutS--><!--ffutS--><!--ffutS--><!--ffutS--><!--ffutS-->{{<!--ffutS--><!--f...'</td><td>3038</td><td>!N</td><td>List(null, null, null, null, null, null, null)</td><td>false</td><td>true</td><td>false</td><td>true</td><td>user</td><td>User:Sikandar khan67/tidEtnoDesaelP</td><td>http://en.wikipedia.org/wiki/User:Sikandar_khan67/tidEtnoDesaelP</td><td>2021-05-18T13:35:46.960Z</td><td>https://en.wikipedia.org/w/index.php?oldid=1023809702&rcid=1385232501</td><td>Sikandar khan67</td><td>http://en.wikipedia.org/wiki/User:Sikandar khan67</td><td>http://en.wikipedia.org</td><td>en</td></tr><tr><td>1969-12-31T23:59:59.999+0000</td><td>#en.wikipedia</td><td>New user account</td><td>null</td><td>create</td><td>List(null, null, null, null, null, null, null)</td><td>false</td><td>false</td><td>false</td><td>false</td><td>special</td><td>Special:Log/newusers</td><td>http://en.wikipedia.org/wiki/Special:Log/newusers</td><td>2021-05-18T13:35:47.026Z</td><td></td><td>Stratfordapt</td><td>http://en.wikipedia.org/wiki/User:Stratfordapt</td><td>http://en.wikipedia.org</td><td>en</td></tr><tr><td>1969-12-31T23:59:59.999+0000</td><td>#en.wikipedia</td><td>/* Main beliefs */</td><td>29</td><td></td><td>List(null, United States, US, USA, null, 38.0, 38.0)</td><td>true</td><td>false</td><td>false</td><td>false</td><td>article</td><td>Anti-Federalism</td><td>http://en.wikipedia.org/wiki/Anti-Federalism</td><td>2021-05-18T13:35:47.092Z</td><td>https://en.wikipedia.org/w/index.php?diff=1023809698&oldid=1023809654</td><td>172.58.207.92</td><td>http://en.wikipedia.org/wiki/User:172.58.207.92</td><td>http://en.wikipedia.org</td><td>en</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import unix_timestamp, col

(spark.readStream
  .format("delta")
  .load(bronzePath)
  .select(col("wikipedia"),
          col("isAnonymous"),
          col("namespace"),
          col("page"),
          col("pageURL"),
          col("geocoding"),
          unix_timestamp(col("timestamp"), "yyyy-MM-dd'T'HH:mm:ss.SSSX").cast("timestamp").alias("timestamp"),
          col("user"))
  .writeStream
  .format("delta")
  .option("checkpointLocation", checkpointPath + "/silver")
  .outputMode("append")
  .queryName("stream_2p")
  .start(silverPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f61af57e580&gt;</div>

# %% [markdown]
# Wait until the stream is done initializing...

# %%
untilStreamIsReady("stream_2p")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream is active and ready.
# </div>

# %%
silverDF = spark.sql("SELECT * FROM delta.`{}` limit 3".format(silverPath))
display(silverDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>wikipedia</th><th>isAnonymous</th><th>namespace</th><th>page</th><th>pageURL</th><th>geocoding</th><th>timestamp</th><th>user</th></tr></thead><tbody><tr><td>en</td><td>true</td><td>article</td><td>GMC Hummer EV</td><td>http://en.wikipedia.org/wiki/GMC_Hummer_EV</td><td>List(null, United States, US, USA, null, 39.7599983215332, 39.7599983215332)</td><td>2021-05-18T13:37:05.000+0000</td><td>2600:6C64:507F:E6E1:4521:AFF8:5B35:BA8A</td></tr><tr><td>en</td><td>false</td><td>article</td><td>Hamza ibn Abdul-Muttalib</td><td>http://en.wikipedia.org/wiki/Hamza_ibn_Abdul-Muttalib</td><td>List(null, null, null, null, null, null, null)</td><td>2021-05-18T13:37:05.000+0000</td><td>Iylaq</td></tr><tr><td>en</td><td>false</td><td>article</td><td>Lucius Aurelius Agaclytus</td><td>http://en.wikipedia.org/wiki/Lucius_Aurelius_Agaclytus</td><td>List(null, null, null, null, null, null, null)</td><td>2021-05-18T13:37:06.000+0000</td><td>*Treker</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col, desc, count

goldDF = (spark.readStream
  .format("delta")
  .load(silverPath)
  .withColumn("countryCode", col("geocoding.countryCode3"))
  .filter(col("namespace") == "article")
  .filter(col("countryCode") != "null")
  .filter(col("isAnonymous") == True)
  .groupBy(col("countryCode"))
  .count() 
  .withColumnRenamed("count", "total")
  .orderBy(col("total").desc())
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Creating Visualizations (aka "platinum" level)

# %%
display(goldDF, streamName = "stream_3p")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>countryCode</th><th>total</th></tr></thead><tbody><tr><td>GBR</td><td>38</td></tr><tr><td>USA</td><td>36</td></tr><tr><td>AUS</td><td>7</td></tr><tr><td>IND</td><td>7</td></tr><tr><td>POL</td><td>7</td></tr><tr><td>IDN</td><td>4</td></tr><tr><td>BRA</td><td>3</td></tr><tr><td>SWE</td><td>3</td></tr><tr><td>AZE</td><td>3</td></tr><tr><td>CAN</td><td>3</td></tr><tr><td>ARE</td><td>3</td></tr><tr><td>ITA</td><td>3</td></tr><tr><td>BEL</td><td>3</td></tr><tr><td>RUS</td><td>3</td></tr><tr><td>DEU</td><td>2</td></tr><tr><td>JPN</td><td>2</td></tr><tr><td>PRT</td><td>2</td></tr><tr><td>NLD</td><td>2</td></tr><tr><td>SRB</td><td>2</td></tr><tr><td>IRL</td><td>2</td></tr><tr><td>ISR</td><td>2</td></tr><tr><td>LKA</td><td>1</td></tr><tr><td>MDA</td><td>1</td></tr><tr><td>MEX</td><td>1</td></tr><tr><td>ZAF</td><td>1</td></tr><tr><td>ESP</td><td>1</td></tr><tr><td>ROU</td><td>1</td></tr><tr><td>SGP</td><td>1</td></tr><tr><td>BRN</td><td>1</td></tr><tr><td>TUR</td><td>1</td></tr><tr><td>THA</td><td>1</td></tr><tr><td>FRA</td><td>1</td></tr><tr><td>SVK</td><td>1</td></tr><tr><td>VNM</td><td>1</td></tr><tr><td>TWN</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# Wait for the streams initialize

# %%
untilStreamIsReady("stream_3p")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream is active and ready.
# </div>

# %% [markdown]
# Make sure all streams are stopped.

# %%
for s in spark.streams.active:
    s.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Batch Pipelines

# %%
# %sh pip install faker
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: faker in /databricks/python3/lib/python3.8/site-packages (8.1.4)
# Requirement already satisfied: python-dateutil&gt;=2.4 in /databricks/python3/lib/python3.8/site-packages (from faker) (2.8.1)
# Requirement already satisfied: text-unidecode==1.3 in /databricks/python3/lib/python3.8/site-packages (from faker) (1.3)
# Requirement already satisfied: six&gt;=1.5 in /usr/local/lib/python3.8/site-packages (from python-dateutil&gt;=2.4-&gt;faker) (1.15.0)
# WARNING: You are using pip version 20.2.4; however, version 21.1.1 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.
# </div>

# %%
# %python
####FUNCTIONS
import pandas as pd
from faker import Factory
import pandas as pd
import random

from faker import Faker
fake = Faker()

###VARIABLE DEFINITIONS
c_current_cdemo_sk = ["c1", "c2", "c3", "c4", "c5"]
c_current_hdemo_sk = ["h1", "h2", "h3", "h4", "h5"]
salutations = ["Mr.", "Mrs.", "Ms", "Dr", "Prof", "None"]
print("customer_id : ", fake.uuid4())
print("customer_sk : ", fake.sha256())
print("current_cdemo_sk : ", fake.words(1, c_current_cdemo_sk, True))
print("current_hdemo_sk : ", fake.words(1, c_current_hdemo_sk, True))
print("current_addr_sk : ", fake.address())
print("first_shipto_date_sk", fake.date())
print("c_first_sales_date_sk", fake.date())
print("c_salutation : ", fake.words(1, salutations, True)[0])
print("c_first_name : ", fake.first_name())
print("c_last_name : ", fake.last_name())
print("c_preferred_cust_flag : ", fake.words(1, ["Y", "N"], True)[0])
print("c_birth_year : ", fake.year())
print("c_birth_country : ", fake.words(1, ["AB", "BC", "CD"], True)[0])
print("c_email_address : ", fake.email())
print("c_last_review_date : ", fake.date())


df1 = pd.DataFrame(columns=("c_customer_id", "c_customer_sk", "c_current_cdemo_sk", "c_current_hdemo_sk", "c_first_shipto_date_sk", "c_first_sales_date_sk", "c_first_name", "c_last_name", "c_preferred_cust_flag", "c_email_address", "c_last_review_date"))

for i in range(100):
  userRecord = [fake.uuid4(), \
                fake.sha256(), \
                fake.words(1, c_current_cdemo_sk, True)[0], \
                fake.words(1, c_current_hdemo_sk, True)[0], \
                fake.date(), \
                fake.date(), \
                fake.first_name(), \
                fake.last_name(), \
                fake.words(1, ["Y", "N"], True)[0], \
                fake.email(), \
                fake.date()] 
  df1.loc[i] = [item for item in userRecord]
  
  
customer_data_bronze = spark.createDataFrame(df1)
display(customer_data_bronze)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">customer_id :  4bf873ce-07cb-409d-8a5d-659865a9b91c
# customer_sk :  4e26cc1ec51a954993922cedcbb04db3a0b61f17b385b089ecd02a6a54916ccd
# current_cdemo_sk :  [&#39;c5&#39;]
# current_hdemo_sk :  [&#39;h4&#39;]
# current_addr_sk :  0786 Wilson Center Suite 832
# New Desiree, NY 64132
# first_shipto_date_sk 1975-05-01
# c_first_sales_date_sk 2010-01-09
# c_salutation :  Mrs.
# c_first_name :  Matthew
# c_last_name :  Brown
# c_preferred_cust_flag :  N
# c_birth_year :  2010
# c_birth_country :  AB
# c_email_address :  emilygreen@gardner.com
# c_last_review_date :  2019-08-24
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
ac947-1f43-4ea2-8e07-b8139f9f99da</td><td>0e61c158aca4438f5dc2da0a1c9a6d8385bc8477c9ffe0eecd8035133a5c1301</td><td>c1</td><td>h3</td><td>2020-04-11</td><td>1971-08-07</td><td>Y</td><td>2002-07-06</td><td>705023d4a04baf3af96c6cd80bed787ebddefd50dc81405bf14005c23d9e7aa9</td></tr><tr><td>102ce1de-db4c-4a66-8617-4b0b94f0953d</td><td>6d5eccdd6e9ac827bc0d991086bc6bfdd110a93a7b746a0b840e8603d7548424</td><td>c4</td><td>h2</td><td>1973-12-15</td><td>1986-08-07</td><td>N</td><td>2015-03-13</td><td>0b4357e25be940a047831fd1824c85d99935ecac5fdceb4d87cea5e0581d339b</td></tr><tr><td>6932d477-1c68-4e71-b43d-d80a47dc9505</td><td>b7fbddda27829b1ac36c0467c1f003b479575f51a5bd109c9b49e2dcf08bae13</td><td>c1</td><td>h4</td><td>2003-03-18</td><td>2011-04-08</td><td>Y</td><td>2004-09-27</td><td>c348c80acc2852d86c8b4a3f85a1a8a0fa0d36aa30d26bbe96f1966a7b7c1933</td></tr><tr><td>33d1bee7-3c76-4b82-88a9-986552fc885d</td><td>1be1df0f1b631779d734543ce6b35679f48c6a9e47333d85da8b65783f3b9668</td><td>c5</td><td>h1</td><td>1987-05-19</td><td>2006-12-02</td><td>Y</td><td>1977-04-29</td><td>794f01c97fdc309bfe68cf4cf8aaf3c92e7a619093ea7fda7f96ee3ba93a94ef</td></tr><tr><td>fa820f81-c35c-4fc2-9f1d-55b6498ee227</td><td>b5c95e3a46a6117c7c01b3583718e82094018711e3c5e9980b63c802738996cb</td><td>c4</td><td>h2</td><td ...

# %% [markdown]
# ###1. Using Databricks SQL for Serving Layer for Businesses and Data Analysts
# ###2. MLflow for ML experiments

# %% [markdown]
# ## Summary
# In this lesson we:
# * Learned about the Databricks Delta (reference) architecture.
# * Used the Databricks Delta architecture to craft bronze, silver, gold and platinum queries.
# * Produced beautiful visualizations of key business metrics.
# * Did not have to explicitly create tables along the way.

# %% [markdown]
# ## Additional Topics & Resources
# * <a href="https://learning.oreilly.com/library/view/delta-lake-the/9781098104580/#" target="_blank">Delta Lake: The Definitive Guide</a>
# * <a href="http://lambda-architecture.net/#" target="_blank">Lambda Architecture</a>
# * <a href="https://bennyaustin.wordpress.com/2010/05/02/kimball-and-inmon-dw-models/#" target="_blank">Data Warehouse Models</a>
# * <a href="https://people.apache.org//~pwendell/spark-nightly/spark-branch-2.1-docs/latest/structured-streaming-kafka-integration.html#" target="_blank">Reading structured streams from Kafka</a>
# * <a href="http://spark.apache.org/docs/latest/structured-streaming-kafka-integration.html#creating-a-kafka-source-stream#" target="_blank">Create a Kafka Source Stream</a>
# * <a href="https://docs.databricks.com/delta/delta-intro.html#case-study-multi-hop-pipelines#" target="_blank">Multi Hop Pipelines</a>

# %% [markdown]
# #######Get in the Early Release of ```Delta Lake: The Definitive Guide```
#
# <img src="https://learning.oreilly.com/library/view/delta-lake-the/9781098104580/assets/cover.png"width=300/>

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
